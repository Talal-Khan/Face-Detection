# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=cv2.imread("hermione.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img.shape
# Out:
# (704, 720, 3)

# %%
roi=img[:400,150:450]
plt.imshow(roi)

# %%
blurred=cv2.GaussianBlur(img,(11,11),0)
plt.imshow(blurred)

# %%
output=img.copy()
cv2.rectangle(output,(520,500),(600,600),(255,0,0),10)
plt.imshow(output)

# %%
blurred=cv2.GaussianBlur(img,(1,11),50)
plt.imshow(blurred)

# %%
blurred=cv2.GaussianBlur(img,(15,1),0)
plt.imshow(blurred)

# %%
faceCascade=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
img=cv2.imread("avengers.jpg")
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
face=faceCascade.detectMultiScale(gray)

for (x,y,w,h) in face:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),5)
    cv2.putText(img,"Face",(x,y),cv2.FONT_HERSHEY_SIMPLEX ,2,(0,0,255))
cv2.imshow("Image",img)
cv2.waitKey()
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
cap=cv2.VideoCapture(0)
faceCascade=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

while(True):
    rot,frame=cap.read()
#     cv2.imshow("preview",frame)
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    face=faceCascade.detectMultiScale(gray)

    for (x,y,w,h) in face:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,255),5)
        cv2.putText(frame,"Hi",(x,y),cv2.FONT_HERSHEY_SIMPLEX ,2,(255,255,255))
    cv2.imshow("Image",frame)
    if cv2.waitKey(1) & 0xFF ==ord(' '):
        break
        
cap.release()
cv2.destroyAllWindows()
